# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cwd = Path("/home/danguyen/data/powertac/evcharger-01/evcharger-01-baseline/29a74826-7bae-4a38-b923-f128b02acdb8/analysis")
bm_transactions = pd.read_csv(cwd/"29a74826-7bae-4a38-b923-f128b02acdb8.balancing-market-transactions.csv", delimiter=";")
tf_transactions = pd.read_csv(cwd/"29a74826-7bae-4a38-b923-f128b02acdb8.tariff-transactions.csv", delimiter=";")

# %%
bm_transactions.head()
# Out:
#    game      broker-name   timeslot           kwh       charge
# 0     0   default broker        360 -29952.280168 -6438.310918
# 1     0   default broker        361  -6455.804813  -684.319028
# 2     0           SPOT19        361   3397.284530   360.114117
# 3     0   default broker        362   3542.825653   435.144363
# 4     0           SPOT19        362   3306.397769   406.105322

# %%
tf_transactions.head()
# Out:
#    game   timeslot      broker-name   tariff-id   tariff-type  \
# 0     0        360   default broker        1885   CONSUMPTION
# 1     0        360   default broker        1885   CONSUMPTION
# 2     0        360   default broker        1885   CONSUMPTION
# 3     0        360   default broker        1885   CONSUMPTION
# 4     0        360   default broker        1885   CONSUMPTION
#
#    transaction-type   transaction-kWh   transaction-charge  \
# 0            SIGNUP               0.0                 -0.0
# 1            SIGNUP               0.0                 -0.0
# 2            SIGNUP               0.0                 -0.0
# 3            SIGNUP               0.0                 -0.0
# 4            SIGNUP               0.0                 -0.0
#
#     transaction-regulation               customer-name   customer-count
# 0                        0           Village 1 NS Base               30
# 1                        0   Village 1 NS Controllable               30
# ...

# %%
df2 = df[df[" timeslot"] < 450].copy()
df2["cumulative_kwh"] = df2.groupby(" broker-name")[" kwh"].cumsum()
df2["cumulative_charge"] = df2.groupby(" broker-name")[" charge"].cumsum()

# %%
f, axes = plt.subplots(2, 2, figsize=(16,9))
sns.lineplot(data = df2, x= " timeslot", y= " kwh", hue = " broker-name", ax = axes[0][0])
sns.lineplot(data = df2, x= " timeslot", y= " charge", hue = " broker-name", ax = axes[0][1])
sns.lineplot(data = df2, x= " timeslot", y= "cumulative_kwh", hue = " broker-name", ax = axes[1][0])
sns.lineplot(data = df2, x= " timeslot", y= "cumulative_charge", hue = " broker-name", ax = axes[1][1])

# %%
df[df[" timeslot"] < 400]
# Out:
#               game          broker-name   timeslot           kwh       charge
# 0    finals_2021_1       default broker        360 -32090.779996 -6966.612460
# 1    finals_2021_1       default broker        361  -3748.149843  -433.998383
# 2    finals_2021_1       default broker        362   2577.857060   283.655460
# 3    finals_2021_1   CrocodileAgent2020        362     -4.400000    -0.484156
# 4    finals_2021_1              TUC_TAC        362 -13199.411080 -1452.402105
# ..             ...                  ...        ...           ...          ...
# 171  finals_2021_1   CrocodileAgent2020        399   -123.620000   -15.348116
# 172  finals_2021_1        COLDPOWER2021        399 -12479.508000 -1566.936853
# 173  finals_2021_1                  IS3        399    569.630000    71.523191
# 174  finals_2021_1              TUC_TAC        399 -14470.647907 -1908.447302
# 175  finals_2021_1         Mertacor2021        399    658.236841    82.648736
#
# [176 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7783 entries, 0 to 7782
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   game          7783 non-null   object
#  1    broker-name  7783 non-null   object
#  2    timeslot     7783 non-null   int64
#  3    kwh          7783 non-null   float64
#  4    charge       7783 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 304.1+ KB

# %%
df.sort_values(by = " timeslot")
# Out:
#                game          broker-name   timeslot           kwh       charge
# 0     finals_2021_1       default broker        360 -32090.779996 -6966.612460
# 1     finals_2021_1       default broker        361  -3748.149843  -433.998383
# 2     finals_2021_1       default broker        362   2577.857060   283.655460
# 3     finals_2021_1   CrocodileAgent2020        362     -4.400000    -0.484156
# 4     finals_2021_1              TUC_TAC        362 -13199.411080 -1452.402105
# ...             ...                  ...        ...           ...          ...
# 7777  finals_2021_1       default broker       1718   3806.661370    80.327347
# 7778  finals_2021_1   CrocodileAgent2020       1718    610.028790    12.878848
# 7779  finals_2021_1        COLDPOWER2021       1718  -3817.646032   -80.559143
# 7780  finals_2021_1                  IS3       1718   7945.050000   192.842758
# 7782  finals_2021_1         Mertacor2021       1718   6113.109894   128.997526
#
# [7783 rows x 5 columns]
